# %% [markdown]
# # 보스턴 집값 예측하기 - 다중선형
#
# ## #01. 패키지 준비하기

# %%
import sys
sys.path.append('../../')
import helper

from pandas import read_excel, DataFrame, merge
from matplotlib import pyplot as plt
import seaborn as sb
import numpy as np

from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from sklearn.model_selection import train_test_split
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.callbacks import ReduceLROnPlateau
from tensorflow.keras.callbacks import ModelCheckpoint

from sklearn.preprocessing import StandardScaler

# %% [markdown]
# ## #02. 데이터셋 준비하기

# %%
origin = read_excel("https://data.hossam.kr/E04/boston.xlsx")
origin.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 506 entries, 0 to 505
# Data columns (total 15 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   CRIM       506 non-null    float64
#  1   ZN         506 non-null    float64
#  2   INDUS      506 non-null    float64
#  3   CHAS       506 non-null    int64
#  4   NOX        506 non-null    float64
#  5   RM         506 non-null    float64
#  6   AGE        506 non-null    float64
#  7   DIS        506 non-null    float64
#  8   RAD        506 non-null    int64
#  9   TAX        506 non-null    int64
#  10  PTRATIO    506 non-null    float64
#  11  B          506 non-null    float64
#  12  LSTAT      506 non-null    float64
#  13  MEDV       506 non-null    float64
#  14  CAT. MEDV  506 non-null    int64
# dtypes: float64(11), int64(4)
# memory usage: 59.4 KB

# %% [markdown]
# ## #03. 데이터 전처리
#
# ### 결측치 확인

# %%
origin.isna().sum()
# Out:
# CRIM         0
# ZN           0
# INDUS        0
# CHAS         0
# NOX          0
# RM           0
# AGE          0
# DIS          0
# RAD          0
# TAX          0
# PTRATIO      0
# B            0
# LSTAT        0
# MEDV         0
# CAT. MEDV    0
# dtype: int64

# %% [markdown]
# ## #04. 탐색적 데이터 분석
#
# ### 명목형 처리

# %%
origin['CHAS'] = origin['CHAS'].astype('category')
origin['CAT. MEDV'] = origin['CAT. MEDV'].astype('category')
origin.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 506 entries, 0 to 505
# Data columns (total 15 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   CRIM       506 non-null    float64
#  1   ZN         506 non-null    float64
#  2   INDUS      506 non-null    float64
#  3   CHAS       506 non-null    category
#  4   NOX        506 non-null    float64
#  5   RM         506 non-null    float64
#  6   AGE        506 non-null    float64
#  7   DIS        506 non-null    float64
#  8   RAD        506 non-null    int64
#  9   TAX        506 non-null    int64
#  10  PTRATIO    506 non-null    float64
#  11  B          506 non-null    float64
#  12  LSTAT      506 non-null    float64
#  13  MEDV       506 non-null    float64
#  14  CAT. MEDV  506 non-null    category
# dtypes: category(2), float64(11), int64(2)
# memory usage: 52.7 KB

# %% [markdown]
# ### 기본통계 확인

# %%
origin.describe()
# Out:
#              CRIM          ZN       INDUS         NOX          RM         AGE  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean     3.613524   11.363636   11.136779    0.554695    6.284634   68.574901
# std      8.601545   23.322453    6.860353    0.115878    0.702617   28.148861
# min      0.006320    0.000000    0.460000    0.385000    3.561000    2.900000
# 25%      0.082045    0.000000    5.190000    0.449000    5.885500   45.025000
# 50%      0.256510    0.000000    9.690000    0.538000    6.208500   77.500000
# 75%      3.677083   12.500000   18.100000    0.624000    6.623500   94.075000
# max     88.976200  100.000000   27.740000    0.871000    8.780000  100.000000
#
#               DIS         RAD         TAX     PTRATIO           B       LSTAT  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean     3.795043    9.549407  408.237154   18.455534  356.674032   12.653063
# std      2.105710    8.707259  168.537116    2.164946   91.294864    7.141062
# min      1.129600    1.000000  187.000000   12.600000    0.320000    1.730000
# 25%      2.100175    4.000000  279.000000   17.400000  375.377500    6.950000
# 50%      3.207450    5.000000  330.000000   19.050000  391.440000   11.360000
# 75%      5.188425   24.000000  666.000000   20.200000  396.225000   16.955000
# max     12.126500   24.000000  711.000000   22.000000  396.900000   37.970000
#
#              MEDV
# count  506.000000
# mean    22.532806
# std      9.197104
# min      5.000000
# 25%     17.025000
# 50%     21.200000
# 75%     25.000000
# max     50.000000

# %% [markdown]
# ### 상자그림

# %%
plt.figure(figsize=(10, 5))
sb.boxplot(data=origin)
plt.show()
plt.close()

# %% [markdown]
# ### 산점도 그래프와 추세선 확인

# %%
# plt.figure(figsize=(30, 30))
# sb.pairplot(origin)
# plt.show()
# plt.close()

# %% [markdown]
# ### 상관계수 확인

# %%
corr = origin.drop('MEDV', axis=1).corr()
corr
# Out:
#                CRIM        ZN     INDUS      CHAS       NOX        RM  \
# CRIM       1.000000 -0.200469  0.406583 -0.055892  0.420972 -0.219247
# ZN        -0.200469  1.000000 -0.533828 -0.042697 -0.516604  0.311991
# INDUS      0.406583 -0.533828  1.000000  0.062938  0.763651 -0.391676
# CHAS      -0.055892 -0.042697  0.062938  1.000000  0.091203  0.091251
# NOX        0.420972 -0.516604  0.763651  0.091203  1.000000 -0.302188
# RM        -0.219247  0.311991 -0.391676  0.091251 -0.302188  1.000000
# AGE        0.352734 -0.569537  0.644779  0.086518  0.731470 -0.240265
# DIS       -0.379670  0.664408 -0.708027 -0.099176 -0.769230  0.205246
# RAD        0.625505 -0.311948  0.595129 -0.007368  0.611441 -0.209847
# TAX        0.582764 -0.314563  0.720760 -0.035587  0.668023 -0.292048
# PTRATIO    0.289946 -0.391679  0.383248 -0.121515  0.188933 -0.355501
# B         -0.385064  0.175520 -0.356977  0.048788 -0.380051  0.128069
# LSTAT      0.455621 -0.412995  0.603800 -0.053929  0.590879 -0.613808
# CAT. MEDV -0.151987  0.365296 -0.366276  0.108631 -0.232502  0.641265
#
#                 AGE       DIS       RAD       TAX   PTRATIO         B  \
# CRIM       0.352734 -0.379670  0.625505  0.582764  0.289946 -0.385064
# ZN        -0.569537  0.664408 -0.311948 -0.314563 -0.391679  0.175520
# INDUS      0.644779 -0.708027  0.595129  0.720760  0.383248 -0.356977
# CHAS       0.086518 -0.099176 -0.007368 -0.035587 -0.121515  0.048788
# NOX        0.731470 -0.769230  0.611441  0.668023  0.188933 -0.380051
# RM        -0.240265  0.205246 -0.209847 -0.292048 -0.355501  0.128069
# AGE        1.000000 -0.747881  0.456022  0.506456  0.261515 -0.273534
# DIS       -0.747881  1.000000 -0.494588 -0.534432 -0.232471  0.291512
# RAD        0.456022 -0.494588  1.000000  0.910228  0.464741 -0.444413
# TAX        0.506456 -0.534432  0.910228  1.000000  0.460853 -0.441808
# PTRATIO    0.261515 -0.232471  0.464741  0.460853  1.000000 -0.177383
# B         -0.273534  0.291512 -0.444413 -0.441808 -0.177383  1.000000
# LSTAT      0.602339 -0.496996  0.488676  0.543993  0.374044 -0.366087
# CAT. MEDV -0.191196  0.118887 -0.197924 -0.273687 -0.443425  0.155137
#
#               LSTAT  CAT. MEDV
# CRIM       0.455621  -0.151987
# ZN        -0.412995   0.365296
# INDUS      0.603800  -0.366276
# CHAS      -0.053929   0.108631
# NOX        0.590879  -0.232502
# RM        -0.613808   0.641265
# AGE        0.602339  -0.191196
# DIS       -0.496996   0.118887
# RAD        0.488676  -0.197924
# TAX        0.543993  -0.273687
# PTRATIO    0.374044  -0.443425
# B         -0.366087   0.155137
# LSTAT      1.000000  -0.469911
# CAT. MEDV -0.469911   1.000000

# %% [markdown]
# ### 상관계수 히트맵

# %%
plt.figure(figsize=(15, 10))
sb.heatmap(corr, annot = True, cmap = 'Greens', vmin = -1, vmax=1, linewidths=.5)
plt.show()
plt.close()

# %% [markdown]
# ### 제외하기로 한 독립변수 제거
#
# > 상관계수의 절대값이 `0.7`이상인 항목을 순차적으로 제거하여 회귀분석에 사용할 요인을 선정

# %%
x = origin.drop(['TAX','DIS', 'NOX','INDUS'], axis=1)
x
# Out:
#         CRIM    ZN CHAS     RM   AGE  RAD  PTRATIO       B  LSTAT  MEDV  \
# 0    0.00632  18.0    0  6.575  65.2    1     15.3  396.90   4.98  24.0
# 1    0.02731   0.0    0  6.421  78.9    2     17.8  396.90   9.14  21.6
# 2    0.02729   0.0    0  7.185  61.1    2     17.8  392.83   4.03  34.7
# 3    0.03237   0.0    0  6.998  45.8    3     18.7  394.63   2.94  33.4
# 4    0.06905   0.0    0  7.147  54.2    3     18.7  396.90   5.33  36.2
# ..       ...   ...  ...    ...   ...  ...      ...     ...    ...   ...
# 501  0.06263   0.0    0  6.593  69.1    1     21.0  391.99   9.67  22.4
# 502  0.04527   0.0    0  6.120  76.7    1     21.0  396.90   9.08  20.6
# 503  0.06076   0.0    0  6.976  91.0    1     21.0  396.90   5.64  23.9
# 504  0.10959   0.0    0  6.794  89.3    1     21.0  393.45   6.48  22.0
# 505  0.04741   0.0    0  6.030  80.8    1     21.0  396.90   7.88  11.9
#
#     CAT. MEDV
# 0           0
# 1           0
# 2           1
# 3           1
# 4           1
# ..        ...
# 501         0
# 502         0
# 503         0
# 504         0
# 505         0
#
# [506 rows x 11 columns]

# %%
plt.figure(figsize=(15, 10))
sb.heatmap(x.corr(), annot = True, cmap = 'Greens', vmin = -1, vmax=1, linewidths=.5)
plt.show()
plt.close()

# %%
x.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 506 entries, 0 to 505
# Data columns (total 11 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   CRIM       506 non-null    float64
#  1   ZN         506 non-null    float64
#  2   CHAS       506 non-null    category
#  3   RM         506 non-null    float64
#  4   AGE        506 non-null    float64
#  5   RAD        506 non-null    int64
#  6   PTRATIO    506 non-null    float64
#  7   B          506 non-null    float64
#  8   LSTAT      506 non-null    float64
#  9   MEDV       506 non-null    float64
#  10  CAT. MEDV  506 non-null    category
# dtypes: category(2), float64(8), int64(1)
# memory usage: 36.9 KB

# %% [markdown]
# ### 명목형 변수만 추출

# %%
categorical_df = x.filter(['CHAS', 'CAT. MEDV'])
categorical_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 506 entries, 0 to 505
# Data columns (total 2 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   CHAS       506 non-null    category
#  1   CAT. MEDV  506 non-null    category
# dtypes: category(2)
# memory usage: 1.4 KB

# %% [markdown]
# ### 종속변수만 추출

# %%
y = x['MEDV']
y
# Out:
# 0      24.0
# 1      21.6
# 2      34.7
# 3      33.4
# 4      36.2
#        ...
# 501    22.4
# 502    20.6
# 503    23.9
# 504    22.0
# 505    11.9
# Name: MEDV, Length: 506, dtype: float64

# %% [markdown]
# ### 데이터프레임에서 추출한 필드를 제거

# %%
x.drop(['CHAS', 'CAT. MEDV', 'MEDV'], axis=1, inplace=True)
x.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 506 entries, 0 to 505
# Data columns (total 8 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   CRIM     506 non-null    float64
#  1   ZN       506 non-null    float64
#  2   RM       506 non-null    float64
#  3   AGE      506 non-null    float64
#  4   RAD      506 non-null    int64
#  5   PTRATIO  506 non-null    float64
#  6   B        506 non-null    float64
#  7   LSTAT    506 non-null    float64
# dtypes: float64(7), int64(1)
# memory usage: 31.8 KB

# %% [markdown]
# ### 최종 산점도 행렬 확인

# %%
plt.figure(figsize=(30, 30))
sb.pairplot(x)
plt.show()
plt.savefig("pairplot.png")
plt.close()
# Out:
# c:\Users\leekh\AppData\Local\Programs\Python\Python39\lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %% [markdown]
# ## #05. 데이터셋 분할하기
#
# ### 랜덤시드 고정

# %%
np.random.seed(777)

# %% [markdown]
# ### 데이터 표준화

# %%
x_scaller = StandardScaler()
x_scale = x_scaller.fit_transform(x)
x_scale
# Out:
# array([[-0.41978194,  0.28482986,  0.41367189, ..., -1.45900038,
#          0.44105193, -1.0755623 ],
#        [-0.41733926, -0.48772236,  0.19427445, ..., -0.30309415,
#          0.44105193, -0.49243937],
#        [-0.41734159, -0.48772236,  1.28271368, ..., -0.30309415,
#          0.39642699, -1.2087274 ],
#        ...,
#        [-0.41344658, -0.48772236,  0.98496002, ...,  1.17646583,
#          0.44105193, -0.98304761],
#        [-0.40776407, -0.48772236,  0.72567214, ...,  1.17646583,
#          0.4032249 , -0.86530163],
#        [-0.41500016, -0.48772236, -0.36276709, ...,  1.17646583,
#          0.44105193, -0.66905833]])

# %% [markdown]
# ### 분리해 놓은 명목형 데이터와 결합
#
# 1. 명목형 변수의 값이 `0`, `1` 두 종류밖에 없기 때문에 별도로 더미변수 처리는 필요 없다.
# 2. 표준화의 결과와 병합이 필요하지만 표준화 함수는 리턴타입이 numpy array이므로 이를 다시 DataFrame으로 변환해야만 명목형과 결합이 가능하다.

# %%
x_scale_df = DataFrame(x_scale, columns=x.columns)
x_scale_df
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 506 entries, 0 to 505
# Data columns (total 8 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   CRIM     506 non-null    float64
#  1   ZN       506 non-null    float64
#  2   RM       506 non-null    float64
#  3   AGE      506 non-null    float64
#  4   RAD      506 non-null    float64
#  5   PTRATIO  506 non-null    float64
#  6   B        506 non-null    float64
#  7   LSTAT    506 non-null    float64
# dtypes: float64(8)
# memory usage: 31.8 KB

# %%
x_df = merge(x_scale_df, categorical_df, left_index=True, right_index=True)
x_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 506 entries, 0 to 505
# Data columns (total 10 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   CRIM       506 non-null    float64
#  1   ZN         506 non-null    float64
#  2   RM         506 non-null    float64
#  3   AGE        506 non-null    float64
#  4   RAD        506 non-null    float64
#  5   PTRATIO    506 non-null    float64
#  6   B          506 non-null    float64
#  7   LSTAT      506 non-null    float64
#  8   CHAS       506 non-null    category
#  9   CAT. MEDV  506 non-null    category
# dtypes: category(2), float64(8)
# memory usage: 33.0 KB

# %% [markdown]
# ### 훈련 데이터와 검증 데이터로 분할

# %%
x_train, x_test, y_train, y_test = train_test_split(x_df, y, test_size=0.3, random_state=777)
x_train.shape, x_test.shape, y_train.shape, y_test.shape
# Out:
# ((354, 10), (152, 10), (354,), (152,))

# %% [markdown]
# ## #06. 모델 개발
#
# ### 모델 정의

# %%
model = Sequential()

# 1차원의 데이터를 입력으로 받고, 64개의 출력을 가지는 첫 번째 Dense 층
model.add(Dense(64, activation = 'relu', input_shape = (len(x_train.columns), )))
model.add(Dense(32, activation = 'relu'))

# 하나의 값을 출력 정답의 범위가 정해지지 않기 때문에 활성화 함수는 linear
model.add(Dense(1, activation = 'linear'))

model.compile(optimizer = 'adam', loss = 'mse', metrics = ['mae'])
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 64)                704
#
#  dense_1 (Dense)             (None, 32)                2080
#
#  dense_2 (Dense)             (None, 1)                 33
#
# =================================================================
# Total params: 2817 (11.00 KB)
# Trainable params: 2817 (11.00 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %% [markdown]
# ### 학습하기

# %%
result = model.fit(x_train, y_train, epochs=500, validation_data=(x_test, y_test), callbacks=[
    EarlyStopping(monitor='val_loss', patience=10, verbose=1),
    ReduceLROnPlateau(monitor= "val_loss", patience=3, factor = 0.5, min_lr=0.001, verbose=1)
])
# Out:
# Epoch 1/500
# 12/12 [==============================] - 1s 18ms/step - loss: 580.7440 - mae: 22.3051 - val_loss: 552.5888 - val_mae: 21.7126 - lr: 0.0010
# Epoch 2/500
# 12/12 [==============================] - 0s 5ms/step - loss: 550.5344 - mae: 21.6767 - val_loss: 522.3467 - val_mae: 21.0522 - lr: 0.0010
# Epoch 3/500
# 12/12 [==============================] - 0s 4ms/step - loss: 517.7529 - mae: 20.9709 - val_loss: 487.0600 - val_mae: 20.2642 - lr: 0.0010
# Epoch 4/500
# 12/12 [==============================] - 0s 4ms/step - loss: 478.4248 - mae: 20.0887 - val_loss: 443.3954 - val_mae: 19.2470 - lr: 0.0010
# Epoch 5/500
# 12/12 [==============================] - 0s 5ms/step - loss: 427.6293 - mae: 18.9194 - val_loss: 388.2920 - val_mae: 17.8986 - lr: 0.0010
# Epoch 6/500
# 12/12 [==============================] - 0s 4ms/step - loss: 364.5262 - mae: 17.3530 - val_loss: 321.6421 - val_mae: 16.1377 - lr: 0.0010
# Epoch 7/500
# 12/12 [==============================] - 0s 4ms/step - loss: 289.9308 - mae: 15.3592 - val_loss: 247.4362 - val_mae: 13.9518 - lr: 0.0010
# Epoch 8/500
# 12/12 [==============================] - 0s 4ms/step - loss: 212.5322 - mae: 12.9495 - val_loss: 169.6928 - val_mae: 11.2764 - lr: 0.0010
# Epoch 9/500
# 12/12 [==============================] - 0s 4ms/step - loss: 137.0611 - mae: 10.1116 - val_loss: 106.1613 - val_mae: 8.5674 - lr: 0.0010
# Epoch 10/500
# 12/12 [==============================] - 0s 5ms/step - loss: 80.2355 - mae: 7.4600 - val_loss: 63.5340 - val_mae: 6.3453 - lr: 0.0010
# Epoch 11/500
# 12/12 [==============================] - 0s 4ms/step - loss: 47.1705 - mae: 5.4608 - val_loss: 40.2728 - val_mae: 4.7438 - lr: 0.0010
# Epoch 12/500
# 12/12 [==============================] - 0s 5ms/step - loss: 32.7595 - mae: 4.3303 - val_loss: 30.2747 - val_mae: 3.9945 - lr: 0.0010
# Epoch 13/500
# 12/12 [==============================] - 0s 4ms/step - loss: 26.2651 - mae: 3.8020 - val_loss: 25.3886 - val_mae: 3.6287 - lr: 0.0010
# Epoch 14/500
# 12/12 [==============================] - 0s 11ms/step - loss: 21.9208 - mae: 3.4631 - val_loss: 22.7170 - val_mae: 3.4392 - lr: 0.0010
# Epoch 15/500
# 12/12 [==============================] - 0s 6ms/step - loss: 19.6707 - mae: 3.2530 - val_loss: 21.2453 - val_mae: 3.3565 - lr: 0.0010
# Epoch 16/500
# 12/12 [==============================] - 0s 4ms/step - loss: 18.0521 - mae: 3.1687 - val_loss: 19.6644 - val_mae: 3.3075 - lr: 0.0010
# Epoch 17/500
# 12/12 [==============================] - 0s 5ms/step - loss: 17.3893 - mae: 3.1411 - val_loss: 18.9275 - val_mae: 3.2472 - lr: 0.0010
# Epoch 18/500
# 12/12 [==============================] - 0s 4ms/step - loss: 16.8466 - mae: 3.0818 - val_loss: 18.5283 - val_mae: 3.1856 - lr: 0.0010
# Epoch 19/500
# 12/12 [==============================] - 0s 4ms/step - loss: 16.3604 - mae: 3.0097 - val_loss: 18.3276 - val_mae: 3.1364 - lr: 0.0010
# Epoch 20/500
# 12/12 [==============================] - 0s 4ms/step - loss: 15.9960 - mae: 2.9676 - val_loss: 18.0803 - val_mae: 3.1187 - lr: 0.0010
# Epoch 21/500
# 12/12 [==============================] - 0s 4ms/step - loss: 15.7565 - mae: 2.9378 - val_loss: 17.9408 - val_mae: 3.0995 - lr: 0.0010
# Epoch 22/500
# 12/12 [==============================] - 0s 4ms/step - loss: 15.5466 - mae: 2.9123 - val_loss: 17.6211 - val_mae: 3.0711 - lr: 0.0010
# Epoch 23/500
# 12/12 [==============================] - 0s 4ms/step - loss: 15.3193 - mae: 2.8845 - val_loss: 17.5657 - val_mae: 3.0742 - lr: 0.0010
# Epoch 24/500
# 12/12 [==============================] - 0s 4ms/step - loss: 15.2666 - mae: 2.8690 - val_loss: 17.6423 - val_mae: 3.0870 - lr: 0.0010
# Epoch 25/500
# 12/12 [==============================] - 0s 4ms/step - loss: 14.9551 - mae: 2.8358 - val_loss: 17.2537 - val_mae: 3.0327 - lr: 0.0010
# Epoch 26/500
# 12/12 [==============================] - 0s 5ms/step - loss: 14.8405 - mae: 2.8252 - val_loss: 17.0606 - val_mae: 3.0194 - lr: 0.0010
# Epoch 27/500
# 12/12 [==============================] - 0s 4ms/step - loss: 14.7195 - mae: 2.8062 - val_loss: 16.8319 - val_mae: 2.9995 - lr: 0.0010
# Epoch 28/500
# 12/12 [==============================] - 0s 5ms/step - loss: 14.5554 - mae: 2.7922 - val_loss: 16.5799 - val_mae: 2.9872 - lr: 0.0010
# Epoch 29/500
# 12/12 [==============================] - 0s 4ms/step - loss: 14.4228 - mae: 2.7814 - val_loss: 16.4682 - val_mae: 2.9762 - lr: 0.0010
# Epoch 30/500
# 12/12 [==============================] - 0s 4ms/step - loss: 14.2636 - mae: 2.7612 - val_loss: 16.4293 - val_mae: 2.9797 - lr: 0.0010
# Epoch 31/500
# 12/12 [==============================] - 0s 5ms/step - loss: 14.1792 - mae: 2.7568 - val_loss: 16.4034 - val_mae: 2.9895 - lr: 0.0010
# Epoch 32/500
# 12/12 [==============================] - 0s 4ms/step - loss: 14.0780 - mae: 2.7450 - val_loss: 16.2461 - val_mae: 2.9691 - lr: 0.0010
# Epoch 33/500
# 12/12 [==============================] - 0s 4ms/step - loss: 13.9339 - mae: 2.7301 - val_loss: 16.1255 - val_mae: 2.9505 - lr: 0.0010
# Epoch 34/500
# 12/12 [==============================] - 0s 4ms/step - loss: 13.8177 - mae: 2.7041 - val_loss: 16.1729 - val_mae: 2.9537 - lr: 0.0010
# Epoch 35/500
# 12/12 [==============================] - 0s 4ms/step - loss: 13.7281 - mae: 2.6904 - val_loss: 15.9380 - val_mae: 2.9300 - lr: 0.0010
# Epoch 36/500
# 12/12 [==============================] - 0s 4ms/step - loss: 13.6143 - mae: 2.6819 - val_loss: 15.8921 - val_mae: 2.9304 - lr: 0.0010
# Epoch 37/500
# 12/12 [==============================] - 0s 4ms/step - loss: 13.5011 - mae: 2.6691 - val_loss: 15.8435 - val_mae: 2.9269 - lr: 0.0010
# Epoch 38/500
# 12/12 [==============================] - 0s 5ms/step - loss: 13.4426 - mae: 2.6492 - val_loss: 15.8590 - val_mae: 2.9287 - lr: 0.0010
# Epoch 39/500
# 12/12 [==============================] - 0s 4ms/step - loss: 13.3580 - mae: 2.6361 - val_loss: 15.7315 - val_mae: 2.9185 - lr: 0.0010
# Epoch 40/500
# 12/12 [==============================] - 0s 4ms/step - loss: 13.2769 - mae: 2.6370 - val_loss: 15.6071 - val_mae: 2.9189 - lr: 0.0010
# Epoch 41/500
# 12/12 [==============================] - 0s 7ms/step - loss: 13.2111 - mae: 2.6315 - val_loss: 15.8695 - val_mae: 2.9528 - lr: 0.0010
# Epoch 42/500
# 12/12 [==============================] - 0s 4ms/step - loss: 13.0697 - mae: 2.6290 - val_loss: 15.6320 - val_mae: 2.9234 - lr: 0.0010
# Epoch 43/500
# 12/12 [==============================] - 0s 8ms/step - loss: 12.9433 - mae: 2.6230 - val_loss: 15.4157 - val_mae: 2.9064 - lr: 0.0010
# Epoch 44/500
# 12/12 [==============================] - 0s 6ms/step - loss: 12.8493 - mae: 2.6047 - val_loss: 15.3413 - val_mae: 2.8966 - lr: 0.0010
# Epoch 45/500
# 12/12 [==============================] - 0s 5ms/step - loss: 12.7785 - mae: 2.5976 - val_loss: 15.2213 - val_mae: 2.8896 - lr: 0.0010
# Epoch 46/500
# 12/12 [==============================] - 0s 4ms/step - loss: 12.7277 - mae: 2.6007 - val_loss: 15.0568 - val_mae: 2.8751 - lr: 0.0010
# Epoch 47/500
# 12/12 [==============================] - 0s 4ms/step - loss: 12.6815 - mae: 2.5935 - val_loss: 15.0825 - val_mae: 2.8716 - lr: 0.0010
# Epoch 48/500
# 12/12 [==============================] - 0s 5ms/step - loss: 12.5126 - mae: 2.5623 - val_loss: 15.2145 - val_mae: 2.8948 - lr: 0.0010
# Epoch 49/500
# 12/12 [==============================] - 0s 4ms/step - loss: 12.5351 - mae: 2.5576 - val_loss: 15.0743 - val_mae: 2.8838 - lr: 0.0010
# Epoch 50/500
# 12/12 [==============================] - 0s 4ms/step - loss: 12.3294 - mae: 2.5617 - val_loss: 14.8770 - val_mae: 2.8735 - lr: 0.0010
# Epoch 51/500
# 12/12 [==============================] - 0s 5ms/step - loss: 12.2988 - mae: 2.5639 - val_loss: 14.8718 - val_mae: 2.8665 - lr: 0.0010
# Epoch 52/500
# 12/12 [==============================] - 0s 4ms/step - loss: 12.1920 - mae: 2.5427 - val_loss: 14.8333 - val_mae: 2.8618 - lr: 0.0010
# Epoch 53/500
# 12/12 [==============================] - 0s 4ms/step - loss: 12.1161 - mae: 2.5245 - val_loss: 14.7174 - val_mae: 2.8438 - lr: 0.0010
# Epoch 54/500
# 12/12 [==============================] - 0s 4ms/step - loss: 12.0651 - mae: 2.5286 - val_loss: 14.5465 - val_mae: 2.8359 - lr: 0.0010
# Epoch 55/500
# 12/12 [==============================] - 0s 4ms/step - loss: 12.0486 - mae: 2.5075 - val_loss: 14.7277 - val_mae: 2.8353 - lr: 0.0010
# Epoch 56/500
# 12/12 [==============================] - 0s 4ms/step - loss: 12.0308 - mae: 2.5078 - val_loss: 14.5578 - val_mae: 2.8530 - lr: 0.0010
# Epoch 57/500
# 12/12 [==============================] - 0s 4ms/step - loss: 12.0575 - mae: 2.5328 - val_loss: 14.4492 - val_mae: 2.8414 - lr: 0.0010
# Epoch 58/500
# 12/12 [==============================] - 0s 4ms/step - loss: 11.8015 - mae: 2.5008 - val_loss: 14.4826 - val_mae: 2.8428 - lr: 0.0010
# Epoch 59/500
# 12/12 [==============================] - 0s 4ms/step - loss: 11.6790 - mae: 2.4590 - val_loss: 14.7927 - val_mae: 2.8541 - lr: 0.0010
# Epoch 60/500
# 12/12 [==============================] - 0s 4ms/step - loss: 11.8917 - mae: 2.4590 - val_loss: 14.7566 - val_mae: 2.8710 - lr: 0.0010
# Epoch 61/500
# 12/12 [==============================] - 0s 4ms/step - loss: 11.9137 - mae: 2.4823 - val_loss: 15.1410 - val_mae: 2.9487 - lr: 0.0010
# Epoch 62/500
# 12/12 [==============================] - 0s 4ms/step - loss: 12.0100 - mae: 2.5250 - val_loss: 14.8868 - val_mae: 2.9285 - lr: 0.0010
# Epoch 63/500
# 12/12 [==============================] - 0s 4ms/step - loss: 11.7447 - mae: 2.5030 - val_loss: 14.6431 - val_mae: 2.8775 - lr: 0.0010
# Epoch 64/500
# 12/12 [==============================] - 0s 4ms/step - loss: 11.4252 - mae: 2.4704 - val_loss: 14.2343 - val_mae: 2.8548 - lr: 0.0010
# Epoch 65/500
# 12/12 [==============================] - 0s 5ms/step - loss: 11.4344 - mae: 2.5011 - val_loss: 14.0773 - val_mae: 2.8497 - lr: 0.0010
# Epoch 66/500
# 12/12 [==============================] - 0s 4ms/step - loss: 11.3246 - mae: 2.4560 - val_loss: 14.2762 - val_mae: 2.8398 - lr: 0.0010
# Epoch 67/500
# 12/12 [==============================] - 0s 4ms/step - loss: 11.2676 - mae: 2.4284 - val_loss: 14.1122 - val_mae: 2.8308 - lr: 0.0010
# Epoch 68/500
# 12/12 [==============================] - 0s 4ms/step - loss: 11.1326 - mae: 2.4406 - val_loss: 13.9279 - val_mae: 2.8351 - lr: 0.0010
# Epoch 69/500
# 12/12 [==============================] - 0s 4ms/step - loss: 11.1327 - mae: 2.4533 - val_loss: 13.8835 - val_mae: 2.8287 - lr: 0.0010
# Epoch 70/500
# 12/12 [==============================] - 0s 4ms/step - loss: 11.0938 - mae: 2.4452 - val_loss: 13.9431 - val_mae: 2.8396 - lr: 0.0010
# Epoch 71/500
# 12/12 [==============================] - 0s 4ms/step - loss: 11.0901 - mae: 2.4397 - val_loss: 13.9652 - val_mae: 2.8238 - lr: 0.0010
# Epoch 72/500
# 12/12 [==============================] - 0s 4ms/step - loss: 11.0142 - mae: 2.4109 - val_loss: 13.9865 - val_mae: 2.8265 - lr: 0.0010
# Epoch 73/500
# 12/12 [==============================] - 0s 4ms/step - loss: 10.9291 - mae: 2.4128 - val_loss: 13.6303 - val_mae: 2.7968 - lr: 0.0010
# Epoch 74/500
# 12/12 [==============================] - 0s 9ms/step - loss: 10.9021 - mae: 2.4201 - val_loss: 13.6091 - val_mae: 2.7904 - lr: 0.0010
# Epoch 75/500
# 12/12 [==============================] - 0s 5ms/step - loss: 10.7624 - mae: 2.3884 - val_loss: 13.6521 - val_mae: 2.7665 - lr: 0.0010
# Epoch 76/500
# 12/12 [==============================] - 0s 4ms/step - loss: 10.7783 - mae: 2.3615 - val_loss: 13.8473 - val_mae: 2.7662 - lr: 0.0010
# Epoch 77/500
# 12/12 [==============================] - 0s 4ms/step - loss: 10.8318 - mae: 2.3540 - val_loss: 13.9597 - val_mae: 2.7841 - lr: 0.0010
# Epoch 78/500
# 12/12 [==============================] - 0s 4ms/step - loss: 10.7948 - mae: 2.3507 - val_loss: 13.7312 - val_mae: 2.7570 - lr: 0.0010
# Epoch 79/500
# 12/12 [==============================] - 0s 4ms/step - loss: 10.8049 - mae: 2.3912 - val_loss: 13.3845 - val_mae: 2.7425 - lr: 0.0010
# Epoch 80/500
# 12/12 [==============================] - 0s 4ms/step - loss: 10.5745 - mae: 2.3663 - val_loss: 13.4764 - val_mae: 2.7484 - lr: 0.0010
# Epoch 81/500
# 12/12 [==============================] - 0s 4ms/step - loss: 10.5165 - mae: 2.3525 - val_loss: 13.4455 - val_mae: 2.7680 - lr: 0.0010
# Epoch 82/500
# 12/12 [==============================] - 0s 4ms/step - loss: 10.5248 - mae: 2.3770 - val_loss: 13.3206 - val_mae: 2.7669 - lr: 0.0010
# Epoch 83/500
# 12/12 [==============================] - 0s 5ms/step - loss: 10.3405 - mae: 2.3492 - val_loss: 13.3623 - val_mae: 2.7504 - lr: 0.0010
# Epoch 84/500
# 12/12 [==============================] - 0s 4ms/step - loss: 10.5369 - mae: 2.3475 - val_loss: 13.7857 - val_mae: 2.7727 - lr: 0.0010
# Epoch 85/500
# 12/12 [==============================] - 0s 7ms/step - loss: 10.5047 - mae: 2.3471 - val_loss: 13.6506 - val_mae: 2.7683 - lr: 0.0010
# Epoch 86/500
# 12/12 [==============================] - 0s 4ms/step - loss: 10.2969 - mae: 2.3407 - val_loss: 13.2140 - val_mae: 2.7598 - lr: 0.0010
# Epoch 87/500
# 12/12 [==============================] - 0s 5ms/step - loss: 10.2413 - mae: 2.3553 - val_loss: 13.0680 - val_mae: 2.7558 - lr: 0.0010
# Epoch 88/500
# 12/12 [==============================] - 0s 4ms/step - loss: 10.6070 - mae: 2.4508 - val_loss: 12.9694 - val_mae: 2.8005 - lr: 0.0010
# Epoch 89/500
# 12/12 [==============================] - 0s 4ms/step - loss: 10.5170 - mae: 2.4589 - val_loss: 12.8441 - val_mae: 2.7616 - lr: 0.0010
# Epoch 90/500
# 12/12 [==============================] - 0s 4ms/step - loss: 10.4802 - mae: 2.3714 - val_loss: 13.0648 - val_mae: 2.7420 - lr: 0.0010
# Epoch 91/500
# 12/12 [==============================] - 0s 4ms/step - loss: 10.1403 - mae: 2.3331 - val_loss: 12.7017 - val_mae: 2.7339 - lr: 0.0010
# Epoch 92/500
# 12/12 [==============================] - 0s 4ms/step - loss: 9.9975 - mae: 2.3375 - val_loss: 12.6085 - val_mae: 2.7103 - lr: 0.0010
# Epoch 93/500
# 12/12 [==============================] - 0s 4ms/step - loss: 9.8993 - mae: 2.3208 - val_loss: 12.6087 - val_mae: 2.7085 - lr: 0.0010
# Epoch 94/500
# 12/12 [==============================] - 0s 4ms/step - loss: 9.8265 - mae: 2.3137 - val_loss: 12.7297 - val_mae: 2.7212 - lr: 0.0010
# Epoch 95/500
# 12/12 [==============================] - 0s 4ms/step - loss: 9.8280 - mae: 2.2929 - val_loss: 12.7655 - val_mae: 2.6996 - lr: 0.0010
# Epoch 96/500
# 12/12 [==============================] - 0s 4ms/step - loss: 9.7965 - mae: 2.2816 - val_loss: 12.6843 - val_mae: 2.7100 - lr: 0.0010
# Epoch 97/500
# 12/12 [==============================] - 0s 4ms/step - loss: 9.7666 - mae: 2.2884 - val_loss: 12.8177 - val_mae: 2.7127 - lr: 0.0010
# Epoch 98/500
# 12/12 [==============================] - 0s 5ms/step - loss: 9.7095 - mae: 2.2944 - val_loss: 12.6829 - val_mae: 2.7137 - lr: 0.0010
# Epoch 99/500
# 12/12 [==============================] - 0s 4ms/step - loss: 9.8539 - mae: 2.2877 - val_loss: 12.9523 - val_mae: 2.7279 - lr: 0.0010
# Epoch 100/500
# 12/12 [==============================] - 0s 9ms/step - loss: 9.7475 - mae: 2.2685 - val_loss: 12.8066 - val_mae: 2.6942 - lr: 0.0010
# Epoch 101/500
# 12/12 [==============================] - 0s 7ms/step - loss: 9.6828 - mae: 2.2566 - val_loss: 12.6278 - val_mae: 2.6860 - lr: 0.0010
# Epoch 102/500
# 12/12 [==============================] - 0s 4ms/step - loss: 9.6437 - mae: 2.2582 - val_loss: 12.4678 - val_mae: 2.6855 - lr: 0.0010
# Epoch 103/500
# 12/12 [==============================] - 0s 4ms/step - loss: 9.5429 - mae: 2.2374 - val_loss: 12.5524 - val_mae: 2.6630 - lr: 0.0010
# Epoch 104/500
# 12/12 [==============================] - 0s 4ms/step - loss: 9.6712 - mae: 2.2267 - val_loss: 12.5734 - val_mae: 2.6793 - lr: 0.0010
# Epoch 105/500
# 12/12 [==============================] - 0s 4ms/step - loss: 9.4227 - mae: 2.2269 - val_loss: 12.3770 - val_mae: 2.6857 - lr: 0.0010
# Epoch 106/500
# 12/12 [==============================] - 0s 4ms/step - loss: 9.4300 - mae: 2.2575 - val_loss: 12.3142 - val_mae: 2.6836 - lr: 0.0010
# Epoch 107/500
# 12/12 [==============================] - 0s 7ms/step - loss: 9.4010 - mae: 2.2551 - val_loss: 12.4106 - val_mae: 2.6749 - lr: 0.0010
# Epoch 108/500
# 12/12 [==============================] - 0s 4ms/step - loss: 9.3178 - mae: 2.2300 - val_loss: 12.7252 - val_mae: 2.6995 - lr: 0.0010
# Epoch 109/500
# 12/12 [==============================] - 0s 4ms/step - loss: 9.3701 - mae: 2.2322 - val_loss: 12.6243 - val_mae: 2.6890 - lr: 0.0010
# Epoch 110/500
# 12/12 [==============================] - 0s 4ms/step - loss: 9.3432 - mae: 2.2063 - val_loss: 12.7436 - val_mae: 2.6793 - lr: 0.0010
# Epoch 111/500
# 12/12 [==============================] - 0s 4ms/step - loss: 9.4049 - mae: 2.2167 - val_loss: 12.7485 - val_mae: 2.6970 - lr: 0.0010
# Epoch 112/500
# 12/12 [==============================] - 0s 4ms/step - loss: 9.2024 - mae: 2.2193 - val_loss: 12.2950 - val_mae: 2.6635 - lr: 0.0010
# Epoch 113/500
# 12/12 [==============================] - 0s 4ms/step - loss: 9.2087 - mae: 2.1926 - val_loss: 12.2707 - val_mae: 2.6553 - lr: 0.0010
# Epoch 114/500
# 12/12 [==============================] - 0s 4ms/step - loss: 9.1321 - mae: 2.1837 - val_loss: 12.0609 - val_mae: 2.6391 - lr: 0.0010
# Epoch 115/500
# 12/12 [==============================] - 0s 4ms/step - loss: 8.9982 - mae: 2.1873 - val_loss: 12.0521 - val_mae: 2.6420 - lr: 0.0010
# Epoch 116/500
# 12/12 [==============================] - 0s 4ms/step - loss: 8.9777 - mae: 2.1852 - val_loss: 12.0851 - val_mae: 2.6361 - lr: 0.0010
# Epoch 117/500
# 12/12 [==============================] - 0s 5ms/step - loss: 8.9399 - mae: 2.1858 - val_loss: 12.0526 - val_mae: 2.6476 - lr: 0.0010
# Epoch 118/500
# 12/12 [==============================] - 0s 4ms/step - loss: 8.9797 - mae: 2.2105 - val_loss: 12.0082 - val_mae: 2.6545 - lr: 0.0010
# Epoch 119/500
# 12/12 [==============================] - 0s 4ms/step - loss: 8.9039 - mae: 2.1846 - val_loss: 12.0183 - val_mae: 2.6347 - lr: 0.0010
# Epoch 120/500
# 12/12 [==============================] - 0s 4ms/step - loss: 8.8271 - mae: 2.1756 - val_loss: 11.8909 - val_mae: 2.6391 - lr: 0.0010
# Epoch 121/500
# 12/12 [==============================] - 0s 4ms/step - loss: 8.8686 - mae: 2.1871 - val_loss: 11.8466 - val_mae: 2.6322 - lr: 0.0010
# Epoch 122/500
# 12/12 [==============================] - 0s 4ms/step - loss: 8.8678 - mae: 2.1654 - val_loss: 11.8654 - val_mae: 2.6202 - lr: 0.0010
# Epoch 123/500
# 12/12 [==============================] - 0s 4ms/step - loss: 8.8120 - mae: 2.1830 - val_loss: 11.7913 - val_mae: 2.6430 - lr: 0.0010
# Epoch 124/500
# 12/12 [==============================] - 0s 4ms/step - loss: 8.6558 - mae: 2.1649 - val_loss: 11.8158 - val_mae: 2.6134 - lr: 0.0010
# Epoch 125/500
# 12/12 [==============================] - 0s 4ms/step - loss: 8.7086 - mae: 2.1356 - val_loss: 11.8597 - val_mae: 2.6104 - lr: 0.0010
# Epoch 126/500
# 12/12 [==============================] - 0s 4ms/step - loss: 8.6869 - mae: 2.1356 - val_loss: 11.7972 - val_mae: 2.6158 - lr: 0.0010
# Epoch 127/500
# 12/12 [==============================] - 0s 4ms/step - loss: 8.6295 - mae: 2.1621 - val_loss: 11.9069 - val_mae: 2.6413 - lr: 0.0010
# Epoch 128/500
# 12/12 [==============================] - 0s 8ms/step - loss: 8.5954 - mae: 2.1632 - val_loss: 11.7307 - val_mae: 2.6264 - lr: 0.0010
# Epoch 129/500
# 12/12 [==============================] - 0s 6ms/step - loss: 8.5734 - mae: 2.1489 - val_loss: 11.7611 - val_mae: 2.6163 - lr: 0.0010
# Epoch 130/500
# 12/12 [==============================] - 0s 4ms/step - loss: 8.5914 - mae: 2.1605 - val_loss: 11.7123 - val_mae: 2.6341 - lr: 0.0010
# Epoch 131/500
# 12/12 [==============================] - 0s 5ms/step - loss: 8.5986 - mae: 2.1552 - val_loss: 11.9967 - val_mae: 2.6124 - lr: 0.0010
# Epoch 132/500
# 12/12 [==============================] - 0s 6ms/step - loss: 8.5033 - mae: 2.1271 - val_loss: 11.7257 - val_mae: 2.6029 - lr: 0.0010
# Epoch 133/500
# 12/12 [==============================] - 0s 4ms/step - loss: 8.5819 - mae: 2.1391 - val_loss: 11.9681 - val_mae: 2.6474 - lr: 0.0010
# Epoch 134/500
# 12/12 [==============================] - 0s 4ms/step - loss: 8.4839 - mae: 2.1500 - val_loss: 11.6615 - val_mae: 2.6230 - lr: 0.0010
# Epoch 135/500
# 12/12 [==============================] - 0s 4ms/step - loss: 8.3569 - mae: 2.1404 - val_loss: 11.4977 - val_mae: 2.6291 - lr: 0.0010
# Epoch 136/500
# 12/12 [==============================] - 0s 5ms/step - loss: 8.4876 - mae: 2.1616 - val_loss: 11.4450 - val_mae: 2.6306 - lr: 0.0010
# Epoch 137/500
# 12/12 [==============================] - 0s 4ms/step - loss: 8.3472 - mae: 2.1244 - val_loss: 11.4223 - val_mae: 2.5776 - lr: 0.0010
# Epoch 138/500
# 12/12 [==============================] - 0s 5ms/step - loss: 8.3168 - mae: 2.1198 - val_loss: 11.5276 - val_mae: 2.6052 - lr: 0.0010
# Epoch 139/500
# 12/12 [==============================] - 0s 5ms/step - loss: 8.2997 - mae: 2.1341 - val_loss: 11.5609 - val_mae: 2.6344 - lr: 0.0010
# Epoch 140/500
# 12/12 [==============================] - 0s 5ms/step - loss: 8.2715 - mae: 2.1191 - val_loss: 11.4050 - val_mae: 2.5761 - lr: 0.0010
# Epoch 141/500
# 12/12 [==============================] - 0s 5ms/step - loss: 8.2634 - mae: 2.0814 - val_loss: 11.4016 - val_mae: 2.5602 - lr: 0.0010
# Epoch 142/500
# 12/12 [==============================] - 0s 4ms/step - loss: 8.4269 - mae: 2.1316 - val_loss: 11.7171 - val_mae: 2.6593 - lr: 0.0010
# Epoch 143/500
# 12/12 [==============================] - 0s 5ms/step - loss: 8.4379 - mae: 2.1642 - val_loss: 11.1601 - val_mae: 2.5612 - lr: 0.0010
# Epoch 144/500
# 12/12 [==============================] - 0s 5ms/step - loss: 8.1417 - mae: 2.0799 - val_loss: 11.2550 - val_mae: 2.5435 - lr: 0.0010
# Epoch 145/500
# 12/12 [==============================] - 0s 4ms/step - loss: 8.1265 - mae: 2.0718 - val_loss: 11.1208 - val_mae: 2.5570 - lr: 0.0010
# Epoch 146/500
# 12/12 [==============================] - 0s 6ms/step - loss: 8.0180 - mae: 2.0827 - val_loss: 11.1362 - val_mae: 2.5621 - lr: 0.0010
# Epoch 147/500
# 12/12 [==============================] - 0s 5ms/step - loss: 8.0037 - mae: 2.0860 - val_loss: 11.1530 - val_mae: 2.5721 - lr: 0.0010
# Epoch 148/500
# 12/12 [==============================] - 0s 5ms/step - loss: 8.1133 - mae: 2.1225 - val_loss: 10.9719 - val_mae: 2.5631 - lr: 0.0010
# Epoch 149/500
# 12/12 [==============================] - 0s 9ms/step - loss: 8.1499 - mae: 2.0870 - val_loss: 11.0978 - val_mae: 2.5297 - lr: 0.0010
# Epoch 150/500
# 12/12 [==============================] - 0s 5ms/step - loss: 8.0555 - mae: 2.0935 - val_loss: 10.9751 - val_mae: 2.5519 - lr: 0.0010
# Epoch 151/500
# 12/12 [==============================] - 0s 4ms/step - loss: 7.9767 - mae: 2.0753 - val_loss: 11.4229 - val_mae: 2.5879 - lr: 0.0010
# Epoch 152/500
# 12/12 [==============================] - 0s 4ms/step - loss: 8.0174 - mae: 2.1097 - val_loss: 11.1715 - val_mae: 2.5725 - lr: 0.0010
# Epoch 153/500
# 12/12 [==============================] - 0s 4ms/step - loss: 7.8557 - mae: 2.0826 - val_loss: 10.8677 - val_mae: 2.5395 - lr: 0.0010
# Epoch 154/500
# 12/12 [==============================] - 0s 4ms/step - loss: 7.8403 - mae: 2.0667 - val_loss: 10.8022 - val_mae: 2.5312 - lr: 0.0010
# Epoch 155/500
# 12/12 [==============================] - 0s 4ms/step - loss: 7.7557 - mae: 2.0490 - val_loss: 10.8679 - val_mae: 2.5191 - lr: 0.0010
# Epoch 156/500
# 12/12 [==============================] - 0s 4ms/step - loss: 7.8426 - mae: 2.0405 - val_loss: 10.8849 - val_mae: 2.5327 - lr: 0.0010
# Epoch 157/500
# 12/12 [==============================] - 0s 4ms/step - loss: 8.0731 - mae: 2.1284 - val_loss: 11.0966 - val_mae: 2.6162 - lr: 0.0010
# Epoch 158/500
# 12/12 [==============================] - 0s 4ms/step - loss: 8.2357 - mae: 2.1480 - val_loss: 10.7260 - val_mae: 2.5213 - lr: 0.0010
# Epoch 159/500
# 12/12 [==============================] - 0s 4ms/step - loss: 7.8029 - mae: 2.0635 - val_loss: 10.8059 - val_mae: 2.5278 - lr: 0.0010
# Epoch 160/500
# 12/12 [==============================] - 0s 4ms/step - loss: 7.6297 - mae: 2.0416 - val_loss: 10.8089 - val_mae: 2.5215 - lr: 0.0010
# Epoch 161/500
# 12/12 [==============================] - 0s 5ms/step - loss: 7.5903 - mae: 2.0313 - val_loss: 10.8201 - val_mae: 2.5262 - lr: 0.0010
# Epoch 162/500
# 12/12 [==============================] - 0s 5ms/step - loss: 7.5239 - mae: 2.0271 - val_loss: 10.8891 - val_mae: 2.5478 - lr: 0.0010
# Epoch 163/500
# 12/12 [==============================] - 0s 4ms/step - loss: 7.5093 - mae: 2.0203 - val_loss: 10.9591 - val_mae: 2.5459 - lr: 0.0010
# Epoch 164/500
# 12/12 [==============================] - 0s 4ms/step - loss: 7.7541 - mae: 2.0548 - val_loss: 11.2363 - val_mae: 2.6304 - lr: 0.0010
# Epoch 165/500
# 12/12 [==============================] - 0s 4ms/step - loss: 7.7234 - mae: 2.0369 - val_loss: 10.9367 - val_mae: 2.5411 - lr: 0.0010
# Epoch 166/500
# 12/12 [==============================] - 0s 5ms/step - loss: 7.4719 - mae: 2.0027 - val_loss: 10.9803 - val_mae: 2.5649 - lr: 0.0010
# Epoch 167/500
# 12/12 [==============================] - 0s 4ms/step - loss: 7.4412 - mae: 2.0281 - val_loss: 10.7146 - val_mae: 2.5217 - lr: 0.0010
# Epoch 168/500
# 12/12 [==============================] - 0s 5ms/step - loss: 7.4613 - mae: 1.9891 - val_loss: 10.8366 - val_mae: 2.5225 - lr: 0.0010
# Epoch 169/500
# 12/12 [==============================] - 0s 4ms/step - loss: 7.3902 - mae: 1.9972 - val_loss: 10.9544 - val_mae: 2.5929 - lr: 0.0010
# Epoch 170/500
# 12/12 [==============================] - 0s 4ms/step - loss: 7.8898 - mae: 2.1058 - val_loss: 11.1906 - val_mae: 2.6280 - lr: 0.0010
# Epoch 171/500
# 12/12 [==============================] - 0s 4ms/step - loss: 7.3918 - mae: 1.9890 - val_loss: 10.9752 - val_mae: 2.5078 - lr: 0.0010
# Epoch 172/500
# 12/12 [==============================] - 0s 4ms/step - loss: 7.4577 - mae: 1.9922 - val_loss: 10.9349 - val_mae: 2.5764 - lr: 0.0010
# Epoch 173/500
# 12/12 [==============================] - 0s 11ms/step - loss: 7.5410 - mae: 2.0629 - val_loss: 10.8018 - val_mae: 2.5941 - lr: 0.0010
# Epoch 174/500
# 12/12 [==============================] - 0s 4ms/step - loss: 7.2187 - mae: 1.9981 - val_loss: 10.7576 - val_mae: 2.5256 - lr: 0.0010
# Epoch 175/500
# 12/12 [==============================] - 0s 4ms/step - loss: 7.3407 - mae: 1.9610 - val_loss: 10.6763 - val_mae: 2.5065 - lr: 0.0010
# Epoch 176/500
# 12/12 [==============================] - 0s 4ms/step - loss: 7.1307 - mae: 1.9675 - val_loss: 10.6336 - val_mae: 2.5638 - lr: 0.0010
# Epoch 177/500
# 12/12 [==============================] - 0s 4ms/step - loss: 7.1435 - mae: 1.9847 - val_loss: 10.7070 - val_mae: 2.5328 - lr: 0.0010
# Epoch 178/500
# 12/12 [==============================] - 0s 4ms/step - loss: 7.1216 - mae: 1.9496 - val_loss: 10.6351 - val_mae: 2.5061 - lr: 0.0010
# Epoch 179/500
# 12/12 [==============================] - 0s 5ms/step - loss: 7.0391 - mae: 1.9688 - val_loss: 10.4933 - val_mae: 2.5486 - lr: 0.0010
# Epoch 180/500
# 12/12 [==============================] - 0s 4ms/step - loss: 7.0249 - mae: 1.9779 - val_loss: 10.8367 - val_mae: 2.5569 - lr: 0.0010
# Epoch 181/500
# 12/12 [==============================] - 0s 4ms/step - loss: 7.0408 - mae: 1.9702 - val_loss: 10.8035 - val_mae: 2.5425 - lr: 0.0010
# Epoch 182/500
# 12/12 [==============================] - 0s 4ms/step - loss: 6.9317 - mae: 1.9483 - val_loss: 10.4892 - val_mae: 2.5335 - lr: 0.0010
# Epoch 183/500
# 12/12 [==============================] - 0s 5ms/step - loss: 6.8897 - mae: 1.9545 - val_loss: 10.3068 - val_mae: 2.5079 - lr: 0.0010
# Epoch 184/500
# 12/12 [==============================] - 0s 5ms/step - loss: 6.9702 - mae: 1.9334 - val_loss: 10.4474 - val_mae: 2.5166 - lr: 0.0010
# Epoch 185/500
# 12/12 [==============================] - 0s 5ms/step - loss: 7.0160 - mae: 1.9551 - val_loss: 10.7380 - val_mae: 2.5841 - lr: 0.0010
# Epoch 186/500
# 12/12 [==============================] - 0s 4ms/step - loss: 7.0074 - mae: 1.9293 - val_loss: 10.3848 - val_mae: 2.4841 - lr: 0.0010
# Epoch 187/500
# 12/12 [==============================] - 0s 4ms/step - loss: 6.8063 - mae: 1.9012 - val_loss: 10.3369 - val_mae: 2.4951 - lr: 0.0010
# Epoch 188/500
# 12/12 [==============================] - 0s 4ms/step - loss: 6.7694 - mae: 1.9159 - val_loss: 10.3222 - val_mae: 2.5043 - lr: 0.0010
# Epoch 189/500
# 12/12 [==============================] - 0s 4ms/step - loss: 6.7421 - mae: 1.9059 - val_loss: 10.2340 - val_mae: 2.4895 - lr: 0.0010
# Epoch 190/500
# 12/12 [==============================] - 0s 4ms/step - loss: 6.6915 - mae: 1.8944 - val_loss: 10.0897 - val_mae: 2.4635 - lr: 0.0010
# Epoch 191/500
# 12/12 [==============================] - 0s 10ms/step - loss: 6.6302 - mae: 1.8791 - val_loss: 10.1653 - val_mae: 2.4850 - lr: 0.0010
# Epoch 192/500
# 12/12 [==============================] - 0s 5ms/step - loss: 6.6912 - mae: 1.9228 - val_loss: 10.1411 - val_mae: 2.5020 - lr: 0.0010
# Epoch 193/500
# 12/12 [==============================] - 0s 4ms/step - loss: 6.6029 - mae: 1.8915 - val_loss: 10.2992 - val_mae: 2.5016 - lr: 0.0010
# Epoch 194/500
# 12/12 [==============================] - 0s 4ms/step - loss: 6.8380 - mae: 1.9348 - val_loss: 10.7533 - val_mae: 2.6230 - lr: 0.0010
# Epoch 195/500
# 12/12 [==============================] - 0s 4ms/step - loss: 6.6577 - mae: 1.9314 - val_loss: 10.2259 - val_mae: 2.4752 - lr: 0.0010
# Epoch 196/500
# 12/12 [==============================] - 0s 4ms/step - loss: 6.8408 - mae: 1.9065 - val_loss: 10.1177 - val_mae: 2.4500 - lr: 0.0010
# Epoch 197/500
# 12/12 [==============================] - 0s 4ms/step - loss: 6.5138 - mae: 1.8782 - val_loss: 10.2605 - val_mae: 2.5319 - lr: 0.0010
# Epoch 198/500
# 12/12 [==============================] - 0s 4ms/step - loss: 6.5876 - mae: 1.8912 - val_loss: 10.1394 - val_mae: 2.4702 - lr: 0.0010
# Epoch 199/500
# 12/12 [==============================] - 0s 4ms/step - loss: 6.4342 - mae: 1.8588 - val_loss: 10.1928 - val_mae: 2.4889 - lr: 0.0010
# Epoch 200/500
# 12/12 [==============================] - 0s 4ms/step - loss: 6.4074 - mae: 1.8618 - val_loss: 10.0685 - val_mae: 2.4855 - lr: 0.0010
# Epoch 201/500
# 12/12 [==============================] - 0s 4ms/step - loss: 6.3566 - mae: 1.8677 - val_loss: 10.1163 - val_mae: 2.4932 - lr: 0.0010
# Epoch 202/500
# 12/12 [==============================] - 0s 5ms/step - loss: 6.3514 - mae: 1.8473 - val_loss: 10.0404 - val_mae: 2.4656 - lr: 0.0010
# Epoch 203/500
# 12/12 [==============================] - 0s 4ms/step - loss: 6.2970 - mae: 1.8431 - val_loss: 9.9226 - val_mae: 2.4705 - lr: 0.0010
# Epoch 204/500
# 12/12 [==============================] - 0s 4ms/step - loss: 6.4946 - mae: 1.8927 - val_loss: 10.0378 - val_mae: 2.5218 - lr: 0.0010
# Epoch 205/500
# 12/12 [==============================] - 0s 4ms/step - loss: 6.4638 - mae: 1.8572 - val_loss: 9.9475 - val_mae: 2.4311 - lr: 0.0010
# Epoch 206/500
# 12/12 [==============================] - 0s 4ms/step - loss: 6.3216 - mae: 1.8567 - val_loss: 9.8098 - val_mae: 2.4590 - lr: 0.0010
# Epoch 207/500
# 12/12 [==============================] - 0s 4ms/step - loss: 6.2537 - mae: 1.8427 - val_loss: 9.9940 - val_mae: 2.4427 - lr: 0.0010
# Epoch 208/500
# 12/12 [==============================] - 0s 6ms/step - loss: 6.3101 - mae: 1.8233 - val_loss: 10.1384 - val_mae: 2.4671 - lr: 0.0010
# Epoch 209/500
# 12/12 [==============================] - 0s 5ms/step - loss: 6.1900 - mae: 1.8189 - val_loss: 9.8460 - val_mae: 2.4778 - lr: 0.0010
# Epoch 210/500
# 12/12 [==============================] - 0s 5ms/step - loss: 6.1937 - mae: 1.8402 - val_loss: 9.6437 - val_mae: 2.4270 - lr: 0.0010
# Epoch 211/500
# 12/12 [==============================] - 0s 4ms/step - loss: 6.1937 - mae: 1.8364 - val_loss: 9.9778 - val_mae: 2.4759 - lr: 0.0010
# Epoch 212/500
# 12/12 [==============================] - 0s 4ms/step - loss: 6.2792 - mae: 1.8840 - val_loss: 10.1621 - val_mae: 2.5234 - lr: 0.0010
# Epoch 213/500
# 12/12 [==============================] - 0s 9ms/step - loss: 6.1328 - mae: 1.8349 - val_loss: 10.2054 - val_mae: 2.4883 - lr: 0.0010
# Epoch 214/500
# 12/12 [==============================] - 0s 4ms/step - loss: 6.0869 - mae: 1.8121 - val_loss: 9.9421 - val_mae: 2.4857 - lr: 0.0010
# Epoch 215/500
# 12/12 [==============================] - 0s 4ms/step - loss: 6.0904 - mae: 1.8252 - val_loss: 10.3349 - val_mae: 2.5250 - lr: 0.0010
# Epoch 216/500
# 12/12 [==============================] - 0s 4ms/step - loss: 6.0888 - mae: 1.8099 - val_loss: 9.9877 - val_mae: 2.4557 - lr: 0.0010
# Epoch 217/500
# 12/12 [==============================] - 0s 5ms/step - loss: 6.1129 - mae: 1.8071 - val_loss: 9.8743 - val_mae: 2.4656 - lr: 0.0010
# Epoch 218/500
# 12/12 [==============================] - 0s 4ms/step - loss: 5.9580 - mae: 1.8121 - val_loss: 9.8984 - val_mae: 2.4876 - lr: 0.0010
# Epoch 219/500
# 12/12 [==============================] - 0s 4ms/step - loss: 5.9667 - mae: 1.8109 - val_loss: 9.8413 - val_mae: 2.4598 - lr: 0.0010
# Epoch 220/500
# 12/12 [==============================] - 0s 6ms/step - loss: 5.7753 - mae: 1.7664 - val_loss: 9.8598 - val_mae: 2.4723 - lr: 0.0010
# Epoch 220: early stopping

# %% [markdown]
# ## #07. 학습 결과 평가

# %%
helper.tf_result_plot(result)

evaluate1 = model.evaluate(x_train, y_train)
print("최종 훈련 손실률: %f, 최종 훈련 절대오차: %f" % (evaluate1[0], evaluate1[1]))

evaluate2 = model.evaluate(x_test, y_test)
print("최종 검증 손실률: %f, 최종 검증 절대오차: %f" % (evaluate2[0], evaluate2[1]))
# Out:
# 12/12 [==============================] - 0s 2ms/step - loss: 5.6511 - mae: 1.7408
# 최종 훈련 손실률: 5.651058, 최종 훈련 절대오차: 1.740810
# 5/5 [==============================] - 0s 2ms/step - loss: 9.8598 - mae: 2.4723
# 최종 검증 손실률: 9.859812, 최종 검증 절대오차: 2.472286

# %% [markdown]
# ## #08. 학습 결과 적용

# %% [markdown]
# ### 테스트 데이터에 대한 예측 결과 산정

# %%
train_pred = model.predict(x_train)
test_pred = model.predict(x_test)
# Out:
# 12/12 [==============================] - 0s 1ms/step
# 5/5 [==============================] - 0s 2ms/step

# %% [markdown]
# ### 결과 데이터 셋 구성

# %%
train_df = DataFrame(x_train, columns=x_train.columns)
train_df['관측치'] = y_train.values
train_df['예측치'] = train_pred.flatten()

train_df['훈련오차'] = train_df['관측치']-train_df['예측치']

train_df.head()
# Out:
#          CRIM        ZN        RM       AGE       RAD   PTRATIO         B  \
# 372  0.541569 -0.487722 -0.583589  0.747665  1.661245  0.806576 -0.096421
# 18  -0.327103 -0.487722 -1.180521 -1.137046 -0.637962  1.176466 -0.742112
# 185 -0.413480 -0.487722 -0.187534  0.008005 -0.752922 -0.303094  0.333711
# 57  -0.418851  3.804234  0.757015 -0.998360 -0.523001 -1.551473  0.397194
# 261 -0.358360  0.370669  1.759974  0.740552 -0.523001 -2.522434  0.347526
#
#         LSTAT CHAS CAT. MEDV   관측치        예측치      훈련오차
# 372 -0.528885    1         1  50.0  44.479607  5.520393
# 18  -0.134996    0         0  20.2  19.356203  0.843797
# 185  0.069658    0         0  29.6  20.587109  9.012891
# 57  -1.219941    0         1  31.6  33.031349 -1.431349
# 261 -0.755966    0         1  43.1  40.412025  2.687975

# %%
test_df = DataFrame(x_test, columns=x_train.columns)
test_df['관측치'] = y_test.values
test_df['예측치'] = test_pred.flatten()

test_df['훈련오차'] = test_df['관측치']-test_df['예측치']

test_df.head()
# Out:
#          CRIM        ZN        RM       AGE       RAD   PTRATIO         B  \
# 207 -0.391193 -0.487722 -0.714658  0.146691 -0.637962  0.066796  0.359148
# 425  1.425197 -0.487722 -0.553671  0.953916  1.661245  0.806576 -3.826496
# 408  0.441097 -0.487722 -0.951151  1.042817  1.661245  0.806576 -0.460876
# 63  -0.405796  0.585267  0.680083 -0.895234 -0.178120  0.575395  0.426579
# 290 -0.416442  2.945843  0.821124 -1.446423 -0.637962  0.344213  0.441052
#
#         LSTAT CHAS CAT. MEDV   관측치        예측치      훈련오차
# 207  0.757911    0         0  22.5  19.257540  3.242460
# 425  1.645211    0         0   8.3  10.138956 -1.838956
# 408  1.926960    0         0  17.2  11.074803  6.125197
# 63  -0.441977    0         0  25.0  23.423349  1.576651
# 290 -1.306849    0         0  28.5  29.205864 -0.705864

# %% [markdown]
# ### 실제 결과값과 머신러닝에 의한 예측값 비교

# %%
for key in ['CRIM','ZN','RM','AGE','RAD','PTRATIO','B','LSTAT']:
    helper.regplot(train_df[key], train_df['관측치'], train_df['예측치'], "훈련데이터",
                   test_df[key], test_df['관측치'], test_df['예측치'], "검증데이터",
                   figsize=(15, 5))
